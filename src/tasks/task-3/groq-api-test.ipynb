# %% [markdown]
# # **Closest Bus Station using Haversine**
# ### Importing the necessary libraries

# %%
import groq

# %% [markdown]
# ### Loading the dataset

# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "who are you?",
        }
    ],
    model="llama-3.2-1b-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# I'm an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."

# %%
from groq import Groq

client = Groq()

chat_completion = client.chat.completions.create(
    #
    # Required parameters
    #
    messages=[
        # Set an optional system message. This sets the behavior of the
        # assistant and can be used to provide specific instructions for
        # how it should behave throughout the conversation.
        {"role": "system", "content": "you are a helpful assistant."},
        # Set a user message for the assistant to respond to.
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        },
    ],
    # The language model which will generate the completion.
    model="llama3-8b-8192",
    #
    # Optional parameters
    #
    # Controls randomness: lowering results in less random completions.
    # As the temperature approaches zero, the model will become deterministic
    # and repetitive.
    temperature=0.5,
    # The maximum number of tokens to generate. Requests can use up to
    # 32,768 tokens shared between prompt and completion.
    max_tokens=1024,
    # Controls diversity via nucleus sampling: 0.5 means half of all
    # likelihood-weighted options are considered.
    top_p=1,
    # A stop sequence is a predefined or user-specified text string that
    # signals an AI to stop generating content, ensuring its responses
    # remain focused and concise. Examples include punctuation marks and
    # markers like "[end]".
    stop=None,
    # If set, partial message deltas will be sent.
    stream=False,
)

# Print the completion returned by the LLM.
print(chat_completion.choices[0].message.content)
# Out:
# Fast language models have gained significant attention in recent years due to their ability to process and generate human-like language at an unprecedented scale and speed. Here are some reasons why fast language models are important:
#
# 1. **Improved Conversational AI**: Fast language models enable the development of more conversational AI systems that can understand and respond to users' queries in a more natural and human-like way. This has numerous applications in customer service, chatbots, and virtual assistants.
# 2. **Efficient Language Translation**: Fast language models can quickly translate text from one language to another, facilitating global communication and collaboration. This is particularly important for businesses and organizations that operate globally.
# 3. **Content Generation**: Fast language models can generate large volumes of content, such as articles, social media posts, and product descriptions, at a rapid pace. This can be useful for content marketing, news organizations, and e-commerce platforms.
# 4. **Sentiment Analysis and Opinion Mining**: Fast language models can quickly analyze sentiment and opinions from large datasets, providing valuable insights for businesses, researchers, and policymakers.
# 5. **Text Summarization**: Fast language models can summarize long documents and articles, helping users quickly grasp the main points and key information.
# 6. **Question Answering**: Fast language models can quickly answer complex questions by searching through vast amounts of text data, making them useful for search engines, knowledge graphs, and expert systems.
# 7. **Improved Data Analysis**: Fast language models can quickly analyze large datasets, identifying patterns, trends, and relationships that may not be apparent through traditional data analysis methods.
# 8. **Enhanced Accessibility**: Fast language models can improve accessibility for people with disabilities, such as those who are visually impaired or have difficulty understanding written language.
# 9. **Research and Development**: Fast language models can accelerate research in natural language processing, machine learning, and cognitive computing, leading to breakthroughs in areas like language understanding, machine translation, and speech recognition.
# 10. **Competitive Advantage**: Companies that develop and deploy fast language models can gain a competitive advantage in their respective markets, as they can quickly respond to changing customer needs, analyze large datasets, and generate high-quality content.
#
# In summary, fast language models have the potential to revolutionize various industries and aspects of our lives by enabling faster, more accurate, and more efficient language processing and generation.
